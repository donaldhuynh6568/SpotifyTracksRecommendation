# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
from matplotlib import pyplot as plt
# %matplotlib inline

sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
# Reading in streaming history
df = pd.read_csv('Streaming_7_22.csv', index_col = 0)
df.head()
# Out:
#                                 name          endTime      artistName  \
# 0            brutal___Olivia Rodrigo  7/10/2021 10:23  Olivia Rodrigo
# 1                   Nova___9th House   7/12/2021 6:57       9th House
# 2  Open Up - Durante Remix___Cassian   7/13/2021 0:22         Cassian
# 3                   Mackin'___Futers   7/13/2021 0:55          Futers
# 4                   Mackin'___Futers   7/13/2021 1:02          Futers
#
#                  trackName  msPlayed         datetime  danceability  energy  \
# 0                   brutal     17623  7/10/2021 10:23         0.672   0.526
# 1                     Nova     99285   7/12/2021 6:57         0.762   0.508
# 2  Open Up - Durante Remix    139365   7/13/2021 0:22         0.740   0.712
# 3                  Mackin'      2159   7/13/2021 0:55         0.697   0.922
# 4                  Mackin'    407264   7/13/2021 1:02         0.697   0.922
#
#    key  loudness  ...    tempo            type                      id  \
# 0    4    -6.446  ...  123.999  audio_features  6SRsiMl7w1USE4mFqrOhHC
# 1    3    -9.112  ...   93.510  audio_features  4osgfFTICMkcGbbigdsa53
# 2    5    -7.723  ...  127.001  audio_features  7MalBWjhXYZYvZ01QOro4P
# 3   11    -7.079  ...  127.868  audio_features  7LWz1ZzKJSo6mgFxBLljb9
# 4   11    -7.079  ...  127.868  audio_features  7LWz1ZzKJSo6mgFxBLljb9
#
#                                     uri  \
# 0  spotify:track:6SRsiMl7w1USE4mFqrOhHC
# 1  spotify:track:4osgfFTICMkcGbbigdsa53
# 2  spotify:track:7MalBWjhXYZYvZ01QOro4P
# 3  spotify:track:7LWz1ZzKJSo6mgFxBLljb9
# 4  spotify:track:7LWz1ZzKJSo6mgFxBLljb9
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6SRsiMl7w1US...
# 1  https://api.spotify.com/v1/tracks/4osgfFTICMkc...
# 2  https://api.spotify.com/v1/tracks/7MalBWjhXYZY...
# 3  https://api.spotify.com/v1/tracks/7LWz1ZzKJSo6...
# 4  https://api.spotify.com/v1/tracks/7LWz1ZzKJSo6...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6SRs...       143747
# 1  https://api.spotify.com/v1/audio-analysis/4osg...       302347
# 2  https://api.spotify.com/v1/audio-analysis/7Mal...       291086
# 3  https://api.spotify.com/v1/audio-analysis/7LWz...       407265
# 4  https://api.spotify.com/v1/audio-analysis/7LWz...       407265
#
#   time_signature                albumName                 albumID
# 0              4                     SOUR  6s84u2TUpR3wdUv4NgKA2j
# 1              4                 Novacane  3RYdEXhGHojkTILUdtnRVJ
# 2              4  Open Up (Durante Remix)  1c1v2oCMYceVDJYsTm4DNn
# 3              4                 U Get Me  5oHZ519kQ1YHqBTaExjgEa
# 4              4                 U Get Me  5oHZ519kQ1YHqBTaExjgEa
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (26937, 26)

# %%
df.columns
# Out:
# Index(['name', 'endTime', 'artistName', 'trackName', 'msPlayed', 'datetime',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'albumName', 'albumID'],
#       dtype='object')

# %%
# Checking for null values
df.isnull().any()
# Out:
# name                False
# endTime             False
# artistName          False
# trackName           False
# msPlayed            False
# datetime            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# type                False
# id                  False
# uri                 False
# track_href          False
# analysis_url        False
# duration_ms         False
# time_signature      False
# albumName            True
# albumID             False
# dtype: bool

# %%
# Checking for duplicate entries
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, endTime, artistName, trackName, msPlayed, datetime, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature, albumName, albumID]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26937 entries, 0 to 26936
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              26937 non-null  object
#  1   endTime           26937 non-null  object
#  2   artistName        26937 non-null  object
#  3   trackName         26937 non-null  object
#  4   msPlayed          26937 non-null  int64
#  5   datetime          26937 non-null  object
#  6   danceability      26937 non-null  float64
#  7   energy            26937 non-null  float64
#  8   key               26937 non-null  int64
#  9   loudness          26937 non-null  float64
#  10  mode              26937 non-null  int64
#  11  speechiness       26937 non-null  float64
#  12  acousticness      26937 non-null  float64
#  13  instrumentalness  26937 non-null  float64
#  14  liveness          26937 non-null  float64
#  15  valence           26937 non-null  float64
#  16  tempo             26937 non-null  float64
#  17  type              26937 non-null  object
#  18  id                26937 non-null  object
#  19  uri               26937 non-null  object
#  20  track_href        26937 non-null  object
#  21  analysis_url      26937 non-null  object
#  22  duration_ms       26937 non-null  int64
#  23  time_signature    26937 non-null  int64
#  24  albumName         26933 non-null  object
#  25  albumID           26937 non-null  object
# dtypes: float64(9), int64(5), object(12)
# memory usage: 5.5+ MB

# %%
# Checking if these two columns are the same
df[['msPlayed', 'duration_ms']]
# Out:
#        msPlayed  duration_ms
# 0         17623       143747
# 1         99285       302347
# 2        139365       291086
# 3          2159       407265
# 4        407264       407265
# ...         ...          ...
# 26932    205570       204571
# 26933    207040       206040
# 26934    175693       174693
# 26935    177133       176133
# 26936    168651       167651
#
# [26937 rows x 2 columns]

# %%
from datetime import datetime

# Create new column with minutes listened to
df['minutesPlayed'] = (df['msPlayed'] / 60000).astype('int64')

# Create new column with total length of song in minutes
df['totalMinutes'] = df['duration_ms'] / 60000

df['% Played']= df['minutesPlayed']/df['totalMinutes']

# # Create new columns with song name & artist
df['name'] = df['name'].str.replace('___',' by ')

# # Create artist column
df['artist']= df['name'].str.split('by').str[-1]

# Create columns with only date, time, day, hour, month, year, day name
df['endTime'] = df['endTime'].astype('datetime64[ns]')
df['date'] = [d.date() for d in df['endTime']]
df['time'] = [d.time() for d in df['endTime']]
df['day'] = df['endTime'].dt.day
df['hour'] = df['endTime'].dt.hour
df['month'] = df['endTime'].dt.month_name()
df['year'] = df['endTime'].dt.year
df['dayName'] = df['endTime'].dt.day_name()

# %%
# Saving a copy of this dataframe for later
xy = df.copy()

# %%
df.to_csv('Spotify Streaming Data', index=False)

# %% [markdown]
# ## Data Exploration

# %%
df.head()
# Out:
#                                  name             endTime      artistName  \
# 0            brutal by Olivia Rodrigo 2021-07-10 10:23:00  Olivia Rodrigo
# 1                   Nova by 9th House 2021-07-12 06:57:00       9th House
# 2  Open Up - Durante Remix by Cassian 2021-07-13 00:22:00         Cassian
# 3                   Mackin' by Futers 2021-07-13 00:55:00          Futers
# 4                   Mackin' by Futers 2021-07-13 01:02:00          Futers
#
#                  trackName  msPlayed            datetime  danceability  \
# 0                   brutal     17623 2021-07-10 10:23:00         0.672
# 1                     Nova     99285 2021-07-12 06:57:00         0.762
# 2  Open Up - Durante Remix    139365 2021-07-13 00:22:00         0.740
# 3                  Mackin'      2159 2021-07-13 00:55:00         0.697
# 4                  Mackin'    407264 2021-07-13 01:02:00         0.697
#
#    energy  key  loudness  ...  totalMinutes  % Played           artist  \
# 0   0.526    4    -6.446  ...      2.395783  0.000000   Olivia Rodrigo
# 1   0.508    3    -9.112  ...      5.039117  0.198447        9th House
# 2   0.712    5    -7.723  ...      4.851433  0.412249          Cassian
# 3   0.922   11    -7.079  ...      6.787750  0.000000           Futers
# 4   0.922   11    -7.079  ...      6.787750  0.883945           Futers
#
#          date      time  day  hour month  year   dayName
# 0  2021-07-10  10:23:00   10    10  July  2021  Saturday
# 1  2021-07-12  06:57:00   12     6  July  2021    Monday
# 2  2021-07-13  00:22:00   13     0  July  2021   Tuesday
# 3  2021-07-13  00:55:00   13     0  July  2021   Tuesday
# 4  2021-07-13  01:02:00   13     1  July  2021   Tuesday
#
# [5 rows x 37 columns]

# %%
# What song(s) are the most listened to?

f = plt.figure(figsize=(15,5)) 
f.patch.set_facecolor('w')

song_count  = df['name'].value_counts()
song_count = song_count[:10]
chart = sns.barplot(x= song_count.index, y= song_count.values, alpha=.9, color='green')
plt.title('Top 10 Songs from 2021-2022')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Song', fontsize=12)
chart.set_xticklabels(song_count.index, rotation=30, horizontalalignment='right')

plt.show()

# %%
# Which artists have the most plays?
song_count = df['artistName'].value_counts()
song_count = song_count[:10]
plt.figure(figsize=(15,5))
chart = sns.barplot(song_count.index, song_count.values, alpha=0.9, color='green')
plt.title('Top 10 Artists From 2021-2022')
plt.ylabel('Number of Songs Listened To', fontsize=12)
plt.xlabel('Artist', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(song_count.index, rotation=30,horizontalalignment='right')

plt.show()
# Out:
# c:\Users\kimje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Which artists have the most minutes listened to?

b = df.groupby('artist')['minutesPlayed'].sum().sort_values(ascending=False)[:10].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(b['artist'], b['minutesPlayed'], alpha=0.8, color='green')
plt.title('Artists with Most Time Listened in Minutes')
plt.ylabel('Total Minutes', fontsize=12)
plt.xlabel('Artist', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(b['artist'], rotation=30)

plt.show()
# Out:
# c:\Users\kimje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# How has the amount of music listened to per day changed over the year?
d = df.groupby('date')['minutesPlayed'].sum().reset_index()
chart = sns.relplot(x='date', y='minutesPlayed', kind="line", data=d, color='green').set(title='Timeline of Minutes Played')
#chart.fig.autofmt_xdate()
chart.fig.set_figwidth(15)
chart.fig.set_figheight(5.7)
chart.set(xlabel='Date', ylabel='Minutes Played')

# %%
# Which day of the week has the most minutes listened to?
e = df.groupby('dayName')['minutesPlayed'].sum().sort_values(ascending=False)[:10].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(e['dayName'], e['minutesPlayed'], alpha=0.8, color='green')
plt.title('Days with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Day', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(e['dayName'], rotation=90)

plt.show()
# Out:
# c:\Users\kimje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Which month of the year has the most minutes of music listened to?
e = df.groupby('month')['minutesPlayed'].sum().sort_values(ascending=False)[:12].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(e['month'], e['minutesPlayed'], alpha=0.8, color='green')
plt.title('Months with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Month', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(e['month'], rotation=90)

plt.show()
# Out:
# c:\Users\kimje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# How has the amount of music listened changed over the day?
d = df.groupby('hour')['minutesPlayed'].sum().reset_index()
chart = sns.relplot(x='hour', y='minutesPlayed', kind="line", data=d, color='green').set(title='Timeline of Minutes Played')
#chart.fig.autofmt_xdate()
chart.fig.set_figwidth(15)
chart.fig.set_figheight(5.7)
chart.set(xticks=np.arange(0,23,1))
chart.set(xlabel='Hour', ylabel='Minutes Played')

# %% [markdown]
# ### Understanding the features of each song
#
# acousticness - float - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# danceability - float - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy - float - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
#
# instrumentalness - float - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
#
# liveness - float - Detects the presence of an audience in the recording.
#
# loudness - float - The overall loudness of a track in decibels (dB).
#
# speechiness - float - Speechiness detects the presence of spoken words in a track.
#
# valence - float - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track.
#
# tempo - float - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration
#
# mode - int - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# key - int - The estimated overall key of the track.

# %% [markdown]
# ## Analyzing Top 200 Songs

# %%
# Creating a new dataframe with audio features of top 200 songs
song_count = xy['name'].value_counts()[:200]
xy = xy.loc[xy['name'].isin(song_count.index)].drop_duplicates(subset=['name'])
xy.head()
# Out:
#                                           name             endTime  \
# 6                        You Right by Doja Cat 2021-07-13 01:06:00
# 7    Jazz Club After Hours by Barry Can't Swim 2021-07-13 01:11:00
# 89                       Solaris by Simon Doty 2021-07-15 23:03:00
# 115                         Hildegard by Dusky 2021-07-17 05:52:00
# 127           Coral Castle by Chaos In The CBD 2021-07-17 07:01:00
#
#            artistName              trackName  msPlayed            datetime  \
# 6            Doja Cat              You Right     38870 2021-07-13 01:06:00
# 7    Barry Can't Swim  Jazz Club After Hours    294211 2021-07-13 01:11:00
# 89         Simon Doty                Solaris    218847 2021-07-15 23:03:00
# 115             Dusky              Hildegard      3970 2021-07-17 05:52:00
# 127  Chaos In The CBD           Coral Castle    401791 2021-07-17 07:01:00
#
#      danceability  energy  key  loudness  ...  totalMinutes  % Played  \
# 6           0.828   0.621    8    -6.414  ...      3.102883  0.000000
# 7           0.724   0.681    9   -10.320  ...      4.903517  0.815741
# 89          0.464   0.993    9    -8.183  ...      3.686650  0.813747
# 115         0.655   0.857    7    -7.868  ...      4.697333  0.000000
# 127         0.780   0.990    6    -9.618  ...      6.873733  0.872888
#
#                 artist        date      time  day  hour month  year   dayName
# 6             Doja Cat  2021-07-13  01:06:00   13     1  July  2021   Tuesday
# 7     Barry Can't Swim  2021-07-13  01:11:00   13     1  July  2021   Tuesday
# 89          Simon Doty  2021-07-15  23:03:00   15    23  July  2021  Thursday
# 115              Dusky  2021-07-17  05:52:00   17     5  July  2021  Saturday
# 127   Chaos In The CBD  2021-07-17  07:01:00   17     7  July  2021  Saturday
#
# [5 rows x 37 columns]

# %%
# What is the average value for each audio feature?
for feature in xy[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',]]:
    sns.boxplot(showfliers = False, x=xy[feature])
    plt.show()

# %%
# Understanding how song features relate in the top 200
corr = xy.corr(method='spearman')
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True).set(title='Coorelations Between Audio Features in Top 200 Songs')
# Out:
# [Text(0.5, 1.0, 'Coorelations Between Audio Features in Top 200 Songs')]
